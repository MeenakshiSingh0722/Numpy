# %%
import numpy as np

# %%
a=np.array(4) #scalar 0d tensor
a
# Out:
# array(4)

# %%
a.ndim
# Out:
# 0

# %%
arr=np.array([1,2,3,4]) #vector 1d tensor
arr
# Out:
# array([1, 2, 3, 4])

# %%
 #matrices 2d tensor
 mat=np.array([[1,2,3],[4,5,6]])
 mat
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
mat.ndim
# Out:
# 2
